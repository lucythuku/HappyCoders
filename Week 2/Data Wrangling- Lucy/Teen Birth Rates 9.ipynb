# %%
pip install plotly
# Out:
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 189, in _main
#     status = self.run(options, args)
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 178, in wrapper
#     return func(self, options, args)
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/commands/install.py", line 276, in run
#     wheel_cache = WheelCache(options.cache_dir, options.format_control)
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/cache.py", line 244, in __init__
#     self._ephem_cache = EphemWheelCache(format_control)
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/cache.py", line 215, in __init__
#     self._temp_dir = TempDirectory(
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/utils/temp_dir.py", line 139, in __init__
#     path = self._create(kind)
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages/pip/_internal/utils/temp_dir.py", line 187, in _create
#     tempfile.mkdtemp(prefix=f"pip-{kind}-")
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/tempfile.py", line 347, in mkdtemp
#     prefix, suffix, dir, output_type = _sanitize_params(prefix, suffix, dir)
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/tempfile.py", line 117, in _sanitize_params
#     dir = gettempdir()
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/tempfile.py", line 286, in gettempdir
#     tempdir = _get_default_tempdir()
#   File "/Users/lucythuku/opt/anaconda3/lib/python3.8/tempfile.py", line 218, in _get_default_tempdir
#     raise FileNotFoundError(_errno.ENOENT,
# FileNotFoundError: [Errno 2] No usable temporary directory found in ['/var/folders/d2/6wm33d0x07g1xzz48ssk0p2r0000gn/T/', '/tmp', '/var/tmp', '/usr/tmp', '/Users/lucythuku/Desktop/Data Science/PROJECT-DSO110/HappyCoders/Week 2/Data Wrangling- Lucy']
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash
# Out:
# Collecting dash
#   Downloading dash-2.2.0-py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 3.0 MB/s eta 0:00:01     |███████▏                        | 1.9 MB 3.0 MB/s eta 0:00:03
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: plotly>=5.0.0 in /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages (from dash) (5.6.0)
# Collecting flask-compress
#   Downloading Flask_Compress-1.11-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: Flask>=1.0.4 in /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages (from dash) (1.1.2)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash) (1.1.1)
# Requirement already satisfied: six in /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages (from plotly>=5.0.0->dash) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages (from plotly>=5.0.0->dash) (8.0.1)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-macosx_10_9_x86_64.whl (421 kB)
#      |████████████████████████████████| 421 kB 13.6 MB/s eta 0:00:01
# Installing collected packages: brotli, flask-compress, dash-table, dash-html-components, dash-core-components, dash
# Successfully installed brotli-1.0.9 dash-2.2.0 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-compress-1.11
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # LOAD LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats

# %% [markdown]
# # LOAD DATASET

# %%
TeenBirthRates = pd.read_csv("Teen rates by state.csv")

# %%
TeenBirthRates.head()
# Out:
#    YEAR STATE  RATE                                       URL
# 0  2020    AL  24.8     /nchs/pressroom/states/alabama/al.htm
# 1  2020    AK  17.7      /nchs/pressroom/states/alaska/ak.htm
# 2  2020    AZ  16.6     /nchs/pressroom/states/arizona/az.htm
# 3  2020    AR  27.8    /nchs/pressroom/states/arkansas/ar.htm
# 4  2020    CA  11.0  /nchs/pressroom/states/california/ca.htm

# %%
TeenBirthRates.tail()
# Out:
#      YEAR STATE  RATE                                                URL
# 395  2005    VA  34.4       /nchs/pressroom/states/virginia/virginia.htm
# 396  2005    WA  31.1   /nchs/pressroom/states/washington/washington.htm
# 397  2005    WV  43.4  /nchs/pressroom/states/westvirginia/westvirgin...
# 398  2005    WI  30.3     /nchs/pressroom/states/wisconsin/wisconsin.htm
# 399  2005    WY  43.2         /nchs/pressroom/states/wyoming/wyoming.htm

# %% [markdown]
# ### WRANGLE THE DATA

# %%
TeenBirthRates.drop("URL", axis = 1, inplace=True)

# %%
TeenBirthRates = TeenBirthRates[TeenBirthRates.YEAR != 2005]

# %%
TeenBirthRates.rename(columns={'STATE' : 'STATECODE'}, inplace=True)

# %%
TeenBirthRates.head()
# Out:
#    YEAR STATECODE  RATE
# 0  2020        AL  24.8
# 1  2020        AK  17.7
# 2  2020        AZ  16.6
# 3  2020        AR  27.8
# 4  2020        CA  11.0

# %%
TeenBirthRates.YEAR.describe()
# Out:
# count     350.000000
# mean     2017.000000
# std         2.002863
# min      2014.000000
# 25%      2015.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2020.000000
# Name: YEAR, dtype: float64

# %% [markdown]
# ### LOOK AT THE TREND IN 2014

# %%
###Filter by the year 2014
TeenBirthRates2014 = TeenBirthRates[TeenBirthRates.YEAR == 2014]

# %%
TeenBirthRates2014
# Out:
#      YEAR STATECODE  RATE
# 300  2014        AL  32.0
# 301  2014        AK  27.8
# 302  2014        AZ  29.9
# 303  2014        AR  39.5
# 304  2014        CA  21.1
# 305  2014        CO  20.3
# 306  2014        CT  11.5
# 307  2014        DE  20.7
# 308  2014        FL  22.5
# 309  2014        GA  28.4
# 310  2014        HI  23.1
# 311  2014        ID  23.2
# 312  2014        IL  22.8
# 313  2014        IN  28.0
# 314  2014        IA  19.8
# 315  2014        KS  27.6
# 316  2014        KY  35.3
# 317  2014        LA  35.8
# 318  2014        ME  16.5
# 319  2014        MD  17.8
# 320  2014        MA  10.6
# 321  2014        MI  21.1
# 322  2014        MN  15.5
# 323  2014        MS  38.0
# 324  2014        MO  27.2
# 325  2014        MT  26.4
# 326  2014        NE  22.2
# 327  2014        NV  28.5
# 328  2014        NH  11.0
# 329  2014        NJ  13.1
# 330  2014        NM  37.8
# 331  2014        NY  16.1
# 332  2014        NC  25.9
# 333  2014        ND  23.9
# 334  2014        OH  25.1
# 335  2014        OK  38.5
# 336  2014        OR  20.0
# 337  2014        PA  19.3
# 338  2014        RI  15.8
# 339  2014        SC  28.5
# 340  2014        SD  26.2
# 341  2014        TN  33.0
# 342  2014        TX  37.8
# 343  2014        UT  19.4
# 344  2014        VT  14.2
# 345  2014        VA  18.4
# 346  2014        WA  19.1
# 347  2014        WV  36.6
# 348  2014        WI  18.0
# 349  2014        WY  30.1

# %%
TeenBirthRates2014 = TeenBirthRates2014.groupby('STATECODE', as_index=False).agg(
    min_birth_rate = pd.NamedAgg(column='RATE', aggfunc=min),
    max_birth_rate = pd.NamedAgg(column='RATE', aggfunc=max),
    mean_birth_rate = pd.NamedAgg(column='RATE', aggfunc= np.mean))

TeenBirthRates2014
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 0         AK            27.8            27.8             27.8
# 1         AL            32.0            32.0             32.0
# 2         AR            39.5            39.5             39.5
# 3         AZ            29.9            29.9             29.9
# 4         CA            21.1            21.1             21.1
# 5         CO            20.3            20.3             20.3
# 6         CT            11.5            11.5             11.5
# 7         DE            20.7            20.7             20.7
# 8         FL            22.5            22.5             22.5
# 9         GA            28.4            28.4             28.4
# 10        HI            23.1            23.1             23.1
# 11        IA            19.8            19.8             19.8
# 12        ID            23.2            23.2             23.2
# 13        IL            22.8            22.8             22.8
# 14        IN            28.0            28.0             28.0
# 15        KS            27.6            27.6             27.6
# 16        KY            35.3            35.3             35.3
# 17        LA            35.8            35.8             35.8
# 18        MA            10.6            10.6             10.6
# 19        MD            17.8            17.8             17.8
# 20        ME            16.5            16.5             16.5
# 21        MI            21.1            21.1             21.1
# 22        MN            15.5            15.5             15.5
# 23        MO            27.2            27.2             27.2
# 24        MS            38.0            38.0             38.0
# 25        MT            26.4            26.4             26.4
# 26        NC            25.9            25.9             25.9
# 27        ND            23.9            23.9             23.9
# 28        NE            22.2            22.2             22.2
# 29        NH            11.0            11.0             11.0
# 30        NJ            13.1            13.1             13.1
# 31        NM            37.8            37.8             37.8
# 32        NV            28.5            28.5             28.5
# 33        NY            16.1            16.1             16.1
# 34        OH            25.1            25.1             25.1
# 35        OK            38.5            38.5             38.5
# 36        OR            20.0            20.0             20.0
# 37        PA            19.3            19.3             19.3
# 38        RI            15.8            15.8             15.8
# 39        SC            28.5            28.5             28.5
# 40        SD            26.2            26.2             26.2
# 41        TN            33.0            33.0             33.0
# 42        TX            37.8            37.8             37.8
# 43        UT            19.4            19.4             19.4
# 44        VA            18.4            18.4             18.4
# 45        VT            14.2            14.2             14.2
# 46        WA            19.1            19.1             19.1
# 47        WI            18.0            18.0             18.0
# 48        WV            36.6            36.6             36.6
# 49        WY            30.1            30.1             30.1

# %%
plt.figure(figsize=(14,8))
sns.barplot(x = TeenBirthRates2014.STATECODE, y = TeenBirthRates2014.mean_birth_rate)
plt.xticks(rotation=90)
plt.grid()
plt.title('Mean Teen Birth Rate 2014')
plt.show()

# %%
state_abbreviations = {
    'AL': 'ALABAMA',
    'AK': 'ALASKA',
    'AS': 'AMERICAN SAMOA',
    'AZ': 'ARIZONA',
    'AR': 'ARKANSAS',
    'CA': 'CALIFORNIA',
    'CO': 'COLORADO',
    'CT': 'CONNECTICUT',
    'DE': 'DELAWARE',
    'DC': 'DISTRICT OF COLUMBIA',
    'FL': 'FLORIDA',
    'GA': 'GEORGIA',
    'GU': 'GUAM',
    'HI': 'HAWAII',
    'ID': 'IDAHO',
    'IL': 'ILLINOIS',
    'IN': 'INDIANA',
    'IA': 'IOWA',
    'KS': 'KANSAS',
    'KY': 'KENTUCKY',
    'LA': 'LOUISIANA',
    'ME': 'MAINE',
    'MD': 'MARYLAND',
    'MA': 'MASSACHUSETTS',
    'MI': 'MICHIGAN',
    'MN': 'MINNESOTA',
    'MS': 'MISSISSIPPI',
    'MO': 'MISSOURI',
    'MT': 'MONTANA',
    'NE': 'NEBRASKA',
    'NV': 'NEVADA',
    'NH': 'NEW HAMPSHIRE',
    'NJ': 'NEW JERSEY',
    'NM': 'NEW MEXICO',
    'NY': 'NEW YORK',
    'NC': 'NORTH CAROLINA',
    'ND': 'NORTH DAKOTA',
    'MP':'NORTHERN MARIANA ISLANDS',
    'OH': 'OHIO',
    'OK': 'OKLAHOMA',
    'OR': 'OREGON',
    'PA': 'PENNSYLVANIA',
    'PR': 'PUERTO RICO',
    'RI': 'RHODE ISLAND',
    'SC': 'SOUTH CAROLINA',
    'SD': 'SOUTH DAKOTA',
    'TN': 'TENNESSEE',
    'TX': 'TEXAS',
    'UT': 'UTAH',
    'VT': 'VERMONT',
    'VI': 'VIRGIN ISLANDS',
    'VA': 'VIRGINIA',
    'WA': 'WASHINGTON',
    'WV': 'WEST VIRGINIA',
    'WI': 'WISCONSIN',
    'WY': 'WYOMING'
}

# %%
TeenBirthRates2014['STATE'] = TeenBirthRates2014['STATECODE'].map(state_abbreviations)
TeenBirthRates2014
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate           STATE
# 0         AK            27.8            27.8             27.8          ALASKA
# 1         AL            32.0            32.0             32.0         ALABAMA
# 2         AR            39.5            39.5             39.5        ARKANSAS
# 3         AZ            29.9            29.9             29.9         ARIZONA
# 4         CA            21.1            21.1             21.1      CALIFORNIA
# 5         CO            20.3            20.3             20.3        COLORADO
# 6         CT            11.5            11.5             11.5     CONNECTICUT
# 7         DE            20.7            20.7             20.7        DELAWARE
# 8         FL            22.5            22.5             22.5         FLORIDA
# 9         GA            28.4            28.4             28.4         GEORGIA
# 10        HI            23.1            23.1             23.1          HAWAII
# 11        IA            19.8            19.8             19.8            IOWA
# 12        ID            23.2            23.2             23.2           IDAHO
# 13        IL            22.8            22.8             22.8        ILLINOIS
# 14        IN            28.0            28.0             28.0         INDIANA
# 15        KS            27.6            27.6             27.6          KANSAS
# 16        KY            35.3            35.3             35.3        KENTUCKY
# 17        LA            35.8            35.8             35.8       LOUISIANA
# 18        MA            10.6            10.6             10.6   MASSACHUSETTS
# 19        MD            17.8            17.8             17.8        MARYLAND
# 20        ME            16.5            16.5             16.5           MAINE
# 21        MI            21.1            21.1             21.1        MICHIGAN
# 22        MN            15.5            15.5             15.5       MINNESOTA
# 23        MO            27.2            27.2             27.2        MISSOURI
# 24        MS            38.0            38.0             38.0     MISSISSIPPI
# 25        MT            26.4            26.4             26.4         MONTANA
# 26        NC            25.9            25.9             25.9  NORTH CAROLINA
# 27        ND            23.9            23.9             23.9    NORTH DAKOTA
# 28        NE            22.2            22.2             22.2        NEBRASKA
# 29        NH            11.0            11.0             11.0   NEW HAMPSHIRE
# 30        NJ            13.1            13.1             13.1      NEW JERSEY
# 31        NM            37.8            37.8             37.8      NEW MEXICO
# 32        NV            28.5            28.5             28.5          NEVADA
# 33        NY            16.1            16.1             16.1        NEW YORK
# 34        OH            25.1            25.1             25.1            OHIO
# 35        OK            38.5            38.5             38.5        OKLAHOMA
# 36        OR            20.0            20.0             20.0          OREGON
# 37        PA            19.3            19.3             19.3    PENNSYLVANIA
# 38        RI            15.8            15.8             15.8    RHODE ISLAND
# 39        SC            28.5            28.5             28.5  SOUTH CAROLINA
# 40        SD            26.2            26.2             26.2    SOUTH DAKOTA
# 41        TN            33.0            33.0             33.0       TENNESSEE
# 42        TX            37.8            37.8             37.8           TEXAS
# 43        UT            19.4            19.4             19.4            UTAH
# 44        VA            18.4            18.4             18.4        VIRGINIA
# 45        VT            14.2            14.2             14.2         VERMONT
# 46        WA            19.1            19.1             19.1      WASHINGTON
# 47        WI            18.0            18.0             18.0       WISCONSIN
# 48        WV            36.6            36.6             36.6   WEST VIRGINIA
# 49        WY            30.1            30.1             30.1         WYOMING

# %%
fig = px.choropleth(TeenBirthRates2014,
                    locationmode='USA-states',
                    scope='usa',
                    locations='STATECODE',
                    color='mean_birth_rate',
                    hover_name='STATE',
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="aa6cc5eb-db1f-4951-8601-e99bfd24f344" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa6cc5eb-db1f-4951-8601-e99bfd24f344")) {                    Plotly.newPlot(                        "aa6cc5eb-db1f-4951-8601-e99bfd24f344",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>STATECODE=%{location}<br>mean_birth_rate=%{z}<extra></extra>","hovertext":["ALASKA","ALABAMA","ARKANSAS","ARIZONA","CALIFORNIA","COLORADO","CONNECTICUT","DELAWARE","FLORIDA","GEORGIA","HAWAII","IOWA","IDAHO","ILLINOIS","INDIANA","KANSAS","KENTUCKY","LOUISIANA","MASSACHUSETTS","MARYLAND","MAINE","MICHIGAN","MINNESOTA","MISSOURI","MISSISSIPPI","MONTANA","NORTH CAROLINA","NORTH DAKOTA","NEBRASKA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEVADA","NEW YORK","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","UTAH","VIRGINIA","VERMONT","WASHINGTON","WISCONSIN","WEST VIRGINIA","WYOMING"],"locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[27.8,32.0,39.5,29.9,21.1,20.3,11.5,20.7,22.5,28.4,23.1,19.8,23.2,22.8,28.0,27.6,35.3,35.8,10.6,17.8,16.5,21.1,15.5,27.2,38.0,26.4,25.9,23.9,22.2,11.0,13.1,37.8,28.5,16.1,25.1,38.5,20.0,19.3,15.8,28.5,26.2,33.0,37.8,19.4,18.4,14.2,19.1,18.0,36.6,30.1],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...

# %%
TeenBirthRates2015 = TeenBirthRates[TeenBirthRates.YEAR == 2015]

# %%
TeenBirthRates2015
# Out:
#      YEAR STATECODE  RATE
# 250  2015        AL  30.1
# 251  2015        AK  29.3
# 252  2015        AZ  26.3
# 253  2015        AR  38.0
# 254  2015        CA  19.0
# 255  2015        CO  19.3
# 256  2015        CT  10.1
# 257  2015        DE  18.1
# 258  2015        FL  20.8
# 259  2015        GA  25.6
# 260  2015        HI  20.6
# 261  2015        ID  22.5
# 262  2015        IL  21.1
# 263  2015        IN  26.0
# 264  2015        IA  18.6
# 265  2015        KS  25.5
# 266  2015        KY  32.4
# 267  2015        LA  34.1
# 268  2015        ME  15.4
# 269  2015        MD  17.0
# 270  2015        MA   9.4
# 271  2015        MI  19.4
# 272  2015        MN  13.7
# 273  2015        MS  34.8
# 274  2015        MO  25.0
# 275  2015        MT  25.3
# 276  2015        NE  22.0
# 277  2015        NV  27.6
# 278  2015        NH  10.9
# 279  2015        NJ  12.1
# 280  2015        NM  34.6
# 281  2015        NY  14.6
# 282  2015        NC  23.6
# 283  2015        ND  22.2
# 284  2015        OH  23.2
# 285  2015        OK  34.8
# 286  2015        OR  19.0
# 287  2015        PA  17.7
# 288  2015        RI  14.3
# 289  2015        SC  26.2
# 290  2015        SD  26.4
# 291  2015        TN  30.5
# 292  2015        TX  34.6
# 293  2015        UT  17.6
# 294  2015        VT  11.6
# 295  2015        VA  17.1
# 296  2015        WA  17.6
# 297  2015        WV  31.9
# 298  2015        WI  16.2
# 299  2015        WY  29.2

# %%
TeenBirthRates2015.tail()
# Out:
#      YEAR STATECODE  RATE
# 295  2015        VA  17.1
# 296  2015        WA  17.6
# 297  2015        WV  31.9
# 298  2015        WI  16.2
# 299  2015        WY  29.2

# %%
TeenBirthRates2015 = TeenBirthRates2015.groupby('STATECODE', as_index=False).agg(
    min_birth_rate = pd.NamedAgg(column='RATE', aggfunc=min),
    max_birth_rate = pd.NamedAgg(column='RATE', aggfunc=max),
    mean_birth_rate = pd.NamedAgg(column='RATE', aggfunc=np.mean))

TeenBirthRates2015
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 0         AK            29.3            29.3             29.3
# 1         AL            30.1            30.1             30.1
# 2         AR            38.0            38.0             38.0
# 3         AZ            26.3            26.3             26.3
# 4         CA            19.0            19.0             19.0
# 5         CO            19.3            19.3             19.3
# 6         CT            10.1            10.1             10.1
# 7         DE            18.1            18.1             18.1
# 8         FL            20.8            20.8             20.8
# 9         GA            25.6            25.6             25.6
# 10        HI            20.6            20.6             20.6
# 11        IA            18.6            18.6             18.6
# 12        ID            22.5            22.5             22.5
# 13        IL            21.1            21.1             21.1
# 14        IN            26.0            26.0             26.0
# 15        KS            25.5            25.5             25.5
# 16        KY            32.4            32.4             32.4
# 17        LA            34.1            34.1             34.1
# 18        MA             9.4             9.4              9.4
# 19        MD            17.0            17.0             17.0
# 20        ME            15.4            15.4             15.4
# 21        MI            19.4            19.4             19.4
# 22        MN            13.7            13.7             13.7
# 23        MO            25.0            25.0             25.0
# 24        MS            34.8            34.8             34.8
# 25        MT            25.3            25.3             25.3
# 26        NC            23.6            23.6             23.6
# 27        ND            22.2            22.2             22.2
# 28        NE            22.0            22.0             22.0
# 29        NH            10.9            10.9             10.9
# 30        NJ            12.1            12.1             12.1
# 31        NM            34.6            34.6             34.6
# 32        NV            27.6            27.6             27.6
# 33        NY            14.6            14.6             14.6
# 34        OH            23.2            23.2             23.2
# 35        OK            34.8            34.8             34.8
# 36        OR            19.0            19.0             19.0
# 37        PA            17.7            17.7             17.7
# 38        RI            14.3            14.3             14.3
# 39        SC            26.2            26.2             26.2
# 40        SD            26.4            26.4             26.4
# 41        TN            30.5            30.5             30.5
# 42        TX            34.6            34.6             34.6
# 43        UT            17.6            17.6             17.6
# 44        VA            17.1            17.1             17.1
# 45        VT            11.6            11.6             11.6
# 46        WA            17.6            17.6             17.6
# 47        WI            16.2            16.2             16.2
# 48        WV            31.9            31.9             31.9
# 49        WY            29.2            29.2             29.2

# %%
plt.figure(figsize=(14,8))
sns.barplot(x = TeenBirthRates2015.STATECODE, y = TeenBirthRates2015.mean_birth_rate)
plt.xticks(rotation=90)
plt.grid()
plt.title('Mean Teen Birth Rate 2015')
plt.show()

# %%
TeenBirthRates2015['STATE'] = TeenBirthRates2015['STATECODE'].map(state_abbreviations)
TeenBirthRates2015
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate           STATE
# 0         AK            29.3            29.3             29.3          ALASKA
# 1         AL            30.1            30.1             30.1         ALABAMA
# 2         AR            38.0            38.0             38.0        ARKANSAS
# 3         AZ            26.3            26.3             26.3         ARIZONA
# 4         CA            19.0            19.0             19.0      CALIFORNIA
# 5         CO            19.3            19.3             19.3        COLORADO
# 6         CT            10.1            10.1             10.1     CONNECTICUT
# 7         DE            18.1            18.1             18.1        DELAWARE
# 8         FL            20.8            20.8             20.8         FLORIDA
# 9         GA            25.6            25.6             25.6         GEORGIA
# 10        HI            20.6            20.6             20.6          HAWAII
# 11        IA            18.6            18.6             18.6            IOWA
# 12        ID            22.5            22.5             22.5           IDAHO
# 13        IL            21.1            21.1             21.1        ILLINOIS
# 14        IN            26.0            26.0             26.0         INDIANA
# 15        KS            25.5            25.5             25.5          KANSAS
# 16        KY            32.4            32.4             32.4        KENTUCKY
# 17        LA            34.1            34.1             34.1       LOUISIANA
# 18        MA             9.4             9.4              9.4   MASSACHUSETTS
# 19        MD            17.0            17.0             17.0        MARYLAND
# 20        ME            15.4            15.4             15.4           MAINE
# 21        MI            19.4            19.4             19.4        MICHIGAN
# 22        MN            13.7            13.7             13.7       MINNESOTA
# 23        MO            25.0            25.0             25.0        MISSOURI
# 24        MS            34.8            34.8             34.8     MISSISSIPPI
# 25        MT            25.3            25.3             25.3         MONTANA
# 26        NC            23.6            23.6             23.6  NORTH CAROLINA
# 27        ND            22.2            22.2             22.2    NORTH DAKOTA
# 28        NE            22.0            22.0             22.0        NEBRASKA
# 29        NH            10.9            10.9             10.9   NEW HAMPSHIRE
# 30        NJ            12.1            12.1             12.1      NEW JERSEY
# 31        NM            34.6            34.6             34.6      NEW MEXICO
# 32        NV            27.6            27.6             27.6          NEVADA
# 33        NY            14.6            14.6             14.6        NEW YORK
# 34        OH            23.2            23.2             23.2            OHIO
# 35        OK            34.8            34.8             34.8        OKLAHOMA
# 36        OR            19.0            19.0             19.0          OREGON
# 37        PA            17.7            17.7             17.7    PENNSYLVANIA
# 38        RI            14.3            14.3             14.3    RHODE ISLAND
# 39        SC            26.2            26.2             26.2  SOUTH CAROLINA
# 40        SD            26.4            26.4             26.4    SOUTH DAKOTA
# 41        TN            30.5            30.5             30.5       TENNESSEE
# 42        TX            34.6            34.6             34.6           TEXAS
# 43        UT            17.6            17.6             17.6            UTAH
# 44        VA            17.1            17.1             17.1        VIRGINIA
# 45        VT            11.6            11.6             11.6         VERMONT
# 46        WA            17.6            17.6             17.6      WASHINGTON
# 47        WI            16.2            16.2             16.2       WISCONSIN
# 48        WV            31.9            31.9             31.9   WEST VIRGINIA
# 49        WY            29.2            29.2             29.2         WYOMING

# %%
fig = px.choropleth(TeenBirthRates2015,
                    locationmode='USA-states',
                    scope='usa',
                    locations='STATECODE',
                    color='mean_birth_rate',
                    hover_name='STATE',
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="4ee17c15-f4ad-4f82-8273-6ca35755f039" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ee17c15-f4ad-4f82-8273-6ca35755f039")) {                    Plotly.newPlot(                        "4ee17c15-f4ad-4f82-8273-6ca35755f039",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>STATECODE=%{location}<br>mean_birth_rate=%{z}<extra></extra>","hovertext":["ALASKA","ALABAMA","ARKANSAS","ARIZONA","CALIFORNIA","COLORADO","CONNECTICUT","DELAWARE","FLORIDA","GEORGIA","HAWAII","IOWA","IDAHO","ILLINOIS","INDIANA","KANSAS","KENTUCKY","LOUISIANA","MASSACHUSETTS","MARYLAND","MAINE","MICHIGAN","MINNESOTA","MISSOURI","MISSISSIPPI","MONTANA","NORTH CAROLINA","NORTH DAKOTA","NEBRASKA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEVADA","NEW YORK","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","UTAH","VIRGINIA","VERMONT","WASHINGTON","WISCONSIN","WEST VIRGINIA","WYOMING"],"locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[29.3,30.1,38.0,26.3,19.0,19.3,10.1,18.1,20.8,25.6,20.6,18.6,22.5,21.1,26.0,25.5,32.4,34.1,9.4,17.0,15.4,19.4,13.7,25.0,34.8,25.3,23.6,22.2,22.0,10.9,12.1,34.6,27.6,14.6,23.2,34.8,19.0,17.7,14.3,26.2,26.4,30.5,34.6,17.6,17.1,11.6,17.6,16.2,31.9,29.2],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222 ...

# %%
TeenBirthRates2016 = TeenBirthRates[TeenBirthRates.YEAR == 2016]
TeenBirthRates2016
# Out:
#      YEAR STATECODE  RATE
# 200  2016        AL  28.4
# 201  2016        AK  25.8
# 202  2016        AZ  23.6
# 203  2016        AR  34.6
# 204  2016        CA  17.0
# 205  2016        CO  17.8
# 206  2016        CT   9.4
# 207  2016        DE  19.5
# 208  2016        FL  19.3
# 209  2016        GA  23.6
# 210  2016        HI  19.2
# 211  2016        ID  20.1
# 212  2016        IL  18.7
# 213  2016        IN  23.6
# 214  2016        IA  17.2
# 215  2016        KS  21.9
# 216  2016        KY  30.9
# 217  2016        LA  30.6
# 218  2016        ME  14.7
# 219  2016        MD  15.9
# 220  2016        MA   8.5
# 221  2016        MI  17.7
# 222  2016        MN  12.6
# 223  2016        MS  32.6
# 224  2016        MO  23.4
# 225  2016        MT  23.7
# 226  2016        NE  19.1
# 227  2016        NV  24.2
# 228  2016        NH   9.3
# 229  2016        NJ  11.0
# 230  2016        NM  29.8
# 231  2016        NY  13.2
# 232  2016        NC  21.8
# 233  2016        ND  20.3
# 234  2016        OH  21.8
# 235  2016        OK  33.4
# 236  2016        OR  16.6
# 237  2016        PA  15.8
# 238  2016        RI  12.9
# 239  2016        SC  23.7
# 240  2016        SD  25.1
# 241  2016        TN  28.0
# 242  2016        TX  31.0
# 243  2016        UT  15.6
# 244  2016        VT  10.3
# 245  2016        VA  15.5
# 246  2016        WA  16.6
# 247  2016        WV  29.3
# 248  2016        WI  15.0
# 249  2016        WY  26.1

# %%
TeenBirthRates2016 = TeenBirthRates2016.groupby('STATECODE', as_index=False).agg(
    min_birth_rate = pd.NamedAgg(column='RATE', aggfunc=min),
    max_birth_rate = pd.NamedAgg(column='RATE', aggfunc=max),
    mean_birth_rate = pd.NamedAgg(column='RATE', aggfunc=np.mean))

TeenBirthRates2016
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 0         AK            25.8            25.8             25.8
# 1         AL            28.4            28.4             28.4
# 2         AR            34.6            34.6             34.6
# 3         AZ            23.6            23.6             23.6
# 4         CA            17.0            17.0             17.0
# 5         CO            17.8            17.8             17.8
# 6         CT             9.4             9.4              9.4
# 7         DE            19.5            19.5             19.5
# 8         FL            19.3            19.3             19.3
# 9         GA            23.6            23.6             23.6
# 10        HI            19.2            19.2             19.2
# 11        IA            17.2            17.2             17.2
# 12        ID            20.1            20.1             20.1
# 13        IL            18.7            18.7             18.7
# 14        IN            23.6            23.6             23.6
# 15        KS            21.9            21.9             21.9
# 16        KY            30.9            30.9             30.9
# 17        LA            30.6            30.6             30.6
# 18        MA             8.5             8.5              8.5
# 19        MD            15.9            15.9             15.9
# 20        ME            14.7            14.7             14.7
# 21        MI            17.7            17.7             17.7
# 22        MN            12.6            12.6             12.6
# 23        MO            23.4            23.4             23.4
# 24        MS            32.6            32.6             32.6
# 25        MT            23.7            23.7             23.7
# 26        NC            21.8            21.8             21.8
# 27        ND            20.3            20.3             20.3
# 28        NE            19.1            19.1             19.1
# 29        NH             9.3             9.3              9.3
# 30        NJ            11.0            11.0             11.0
# 31        NM            29.8            29.8             29.8
# 32        NV            24.2            24.2             24.2
# 33        NY            13.2            13.2             13.2
# 34        OH            21.8            21.8             21.8
# 35        OK            33.4            33.4             33.4
# 36        OR            16.6            16.6             16.6
# 37        PA            15.8            15.8             15.8
# 38        RI            12.9            12.9             12.9
# 39        SC            23.7            23.7             23.7
# 40        SD            25.1            25.1             25.1
# 41        TN            28.0            28.0             28.0
# 42        TX            31.0            31.0             31.0
# 43        UT            15.6            15.6             15.6
# 44        VA            15.5            15.5             15.5
# 45        VT            10.3            10.3             10.3
# 46        WA            16.6            16.6             16.6
# 47        WI            15.0            15.0             15.0
# 48        WV            29.3            29.3             29.3
# 49        WY            26.1            26.1             26.1

# %%
plt.figure(figsize=(14,8))
sns.barplot(x = TeenBirthRates2016.STATECODE, y = TeenBirthRates2016.mean_birth_rate)
plt.xticks(rotation=90)
plt.grid()
plt.title('Mean Teen Birth Rate 2016')
plt.show()

# %%
TeenBirthRates2016['STATE'] = TeenBirthRates2016['STATECODE'].map(state_abbreviations)
TeenBirthRates2016
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate           STATE
# 0         AK            25.8            25.8             25.8          ALASKA
# 1         AL            28.4            28.4             28.4         ALABAMA
# 2         AR            34.6            34.6             34.6        ARKANSAS
# 3         AZ            23.6            23.6             23.6         ARIZONA
# 4         CA            17.0            17.0             17.0      CALIFORNIA
# 5         CO            17.8            17.8             17.8        COLORADO
# 6         CT             9.4             9.4              9.4     CONNECTICUT
# 7         DE            19.5            19.5             19.5        DELAWARE
# 8         FL            19.3            19.3             19.3         FLORIDA
# 9         GA            23.6            23.6             23.6         GEORGIA
# 10        HI            19.2            19.2             19.2          HAWAII
# 11        IA            17.2            17.2             17.2            IOWA
# 12        ID            20.1            20.1             20.1           IDAHO
# 13        IL            18.7            18.7             18.7        ILLINOIS
# 14        IN            23.6            23.6             23.6         INDIANA
# 15        KS            21.9            21.9             21.9          KANSAS
# 16        KY            30.9            30.9             30.9        KENTUCKY
# 17        LA            30.6            30.6             30.6       LOUISIANA
# 18        MA             8.5             8.5              8.5   MASSACHUSETTS
# 19        MD            15.9            15.9             15.9        MARYLAND
# 20        ME            14.7            14.7             14.7           MAINE
# 21        MI            17.7            17.7             17.7        MICHIGAN
# 22        MN            12.6            12.6             12.6       MINNESOTA
# 23        MO            23.4            23.4             23.4        MISSOURI
# 24        MS            32.6            32.6             32.6     MISSISSIPPI
# 25        MT            23.7            23.7             23.7         MONTANA
# 26        NC            21.8            21.8             21.8  NORTH CAROLINA
# 27        ND            20.3            20.3             20.3    NORTH DAKOTA
# 28        NE            19.1            19.1             19.1        NEBRASKA
# 29        NH             9.3             9.3              9.3   NEW HAMPSHIRE
# 30        NJ            11.0            11.0             11.0      NEW JERSEY
# 31        NM            29.8            29.8             29.8      NEW MEXICO
# 32        NV            24.2            24.2             24.2          NEVADA
# 33        NY            13.2            13.2             13.2        NEW YORK
# 34        OH            21.8            21.8             21.8            OHIO
# 35        OK            33.4            33.4             33.4        OKLAHOMA
# 36        OR            16.6            16.6             16.6          OREGON
# 37        PA            15.8            15.8             15.8    PENNSYLVANIA
# 38        RI            12.9            12.9             12.9    RHODE ISLAND
# 39        SC            23.7            23.7             23.7  SOUTH CAROLINA
# 40        SD            25.1            25.1             25.1    SOUTH DAKOTA
# 41        TN            28.0            28.0             28.0       TENNESSEE
# 42        TX            31.0            31.0             31.0           TEXAS
# 43        UT            15.6            15.6             15.6            UTAH
# 44        VA            15.5            15.5             15.5        VIRGINIA
# 45        VT            10.3            10.3             10.3         VERMONT
# 46        WA            16.6            16.6             16.6      WASHINGTON
# 47        WI            15.0            15.0             15.0       WISCONSIN
# 48        WV            29.3            29.3             29.3   WEST VIRGINIA
# 49        WY            26.1            26.1             26.1         WYOMING

# %%
fig = px.choropleth(TeenBirthRates2016,
                    locationmode='USA-states',
                    scope='usa',
                    locations='STATECODE',
                    color='mean_birth_rate',
                    hover_name='STATE',
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="3bef7fff-87b6-435d-9d10-14edc9068902" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bef7fff-87b6-435d-9d10-14edc9068902")) {                    Plotly.newPlot(                        "3bef7fff-87b6-435d-9d10-14edc9068902",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>STATECODE=%{location}<br>mean_birth_rate=%{z}<extra></extra>","hovertext":["ALASKA","ALABAMA","ARKANSAS","ARIZONA","CALIFORNIA","COLORADO","CONNECTICUT","DELAWARE","FLORIDA","GEORGIA","HAWAII","IOWA","IDAHO","ILLINOIS","INDIANA","KANSAS","KENTUCKY","LOUISIANA","MASSACHUSETTS","MARYLAND","MAINE","MICHIGAN","MINNESOTA","MISSOURI","MISSISSIPPI","MONTANA","NORTH CAROLINA","NORTH DAKOTA","NEBRASKA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEVADA","NEW YORK","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","UTAH","VIRGINIA","VERMONT","WASHINGTON","WISCONSIN","WEST VIRGINIA","WYOMING"],"locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[25.8,28.4,34.6,23.6,17.0,17.8,9.4,19.5,19.3,23.6,19.2,17.2,20.1,18.7,23.6,21.9,30.9,30.6,8.5,15.9,14.7,17.7,12.6,23.4,32.6,23.7,21.8,20.3,19.1,9.3,11.0,29.8,24.2,13.2,21.8,33.4,16.6,15.8,12.9,23.7,25.1,28.0,31.0,15.6,15.5,10.3,16.6,15.0,29.3,26.1],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222 ...

# %%
TeenBirthRates2017 = TeenBirthRates[TeenBirthRates.YEAR == 2017]
TeenBirthRates2017
# Out:
#      YEAR STATECODE  RATE
# 150  2017        AL  27.0
# 151  2017        AK  22.0
# 152  2017        AZ  22.0
# 153  2017        AR  32.8
# 154  2017        CA  15.1
# 155  2017        CO  16.1
# 156  2017        CT   8.8
# 157  2017        DE  18.5
# 158  2017        FL  18.2
# 159  2017        GA  21.9
# 160  2017        HI  19.1
# 161  2017        ID  18.6
# 162  2017        IL  17.4
# 163  2017        IN  22.8
# 164  2017        IA  16.0
# 165  2017        KS  21.3
# 166  2017        KY  29.0
# 167  2017        LA  29.1
# 168  2017        ME  13.1
# 169  2017        MD  14.2
# 170  2017        MA   8.1
# 171  2017        MI  16.4
# 172  2017        MN  12.1
# 173  2017        MS  31.0
# 174  2017        MO  22.5
# 175  2017        MT  21.2
# 176  2017        NE  18.1
# 177  2017        NV  21.9
# 178  2017        NH   8.4
# 179  2017        NJ  10.3
# 180  2017        NM  27.9
# 181  2017        NY  12.5
# 182  2017        NC  20.6
# 183  2017        ND  16.2
# 184  2017        OH  20.8
# 185  2017        OK  29.7
# 186  2017        OR  15.0
# 187  2017        PA  14.8
# 188  2017        RI  11.4
# 189  2017        SC  21.7
# 190  2017        SD  22.6
# 191  2017        TN  26.6
# 192  2017        TX  27.6
# 193  2017        UT  15.2
# 194  2017        VT  10.1
# 195  2017        VA  15.0
# 196  2017        WA  14.8
# 197  2017        WV  27.1
# 198  2017        WI  13.8
# 199  2017        WY  24.6

# %%
TeenBirthRates2017 = TeenBirthRates2017.groupby('STATECODE', as_index=False).agg(
    min_birth_rate = pd.NamedAgg(column='RATE', aggfunc=min),
    max_birth_rate = pd.NamedAgg(column='RATE', aggfunc=max),
    mean_birth_rate = pd.NamedAgg(column='RATE', aggfunc=np.mean))

TeenBirthRates2017
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 0         AK            22.0            22.0             22.0
# 1         AL            27.0            27.0             27.0
# 2         AR            32.8            32.8             32.8
# 3         AZ            22.0            22.0             22.0
# 4         CA            15.1            15.1             15.1
# 5         CO            16.1            16.1             16.1
# 6         CT             8.8             8.8              8.8
# 7         DE            18.5            18.5             18.5
# 8         FL            18.2            18.2             18.2
# 9         GA            21.9            21.9             21.9
# 10        HI            19.1            19.1             19.1
# 11        IA            16.0            16.0             16.0
# 12        ID            18.6            18.6             18.6
# 13        IL            17.4            17.4             17.4
# 14        IN            22.8            22.8             22.8
# 15        KS            21.3            21.3             21.3
# 16        KY            29.0            29.0             29.0
# 17        LA            29.1            29.1             29.1
# 18        MA             8.1             8.1              8.1
# 19        MD            14.2            14.2             14.2
# 20        ME            13.1            13.1             13.1
# 21        MI            16.4            16.4             16.4
# 22        MN            12.1            12.1             12.1
# 23        MO            22.5            22.5             22.5
# 24        MS            31.0            31.0             31.0
# 25        MT            21.2            21.2             21.2
# 26        NC            20.6            20.6             20.6
# 27        ND            16.2            16.2             16.2
# 28        NE            18.1            18.1             18.1
# 29        NH             8.4             8.4              8.4
# 30        NJ            10.3            10.3             10.3
# 31        NM            27.9            27.9             27.9
# 32        NV            21.9            21.9             21.9
# 33        NY            12.5            12.5             12.5
# 34        OH            20.8            20.8             20.8
# 35        OK            29.7            29.7             29.7
# 36        OR            15.0            15.0             15.0
# 37        PA            14.8            14.8             14.8
# 38        RI            11.4            11.4             11.4
# 39        SC            21.7            21.7             21.7
# 40        SD            22.6            22.6             22.6
# 41        TN            26.6            26.6             26.6
# 42        TX            27.6            27.6             27.6
# 43        UT            15.2            15.2             15.2
# 44        VA            15.0            15.0             15.0
# 45        VT            10.1            10.1             10.1
# 46        WA            14.8            14.8             14.8
# 47        WI            13.8            13.8             13.8
# 48        WV            27.1            27.1             27.1
# 49        WY            24.6            24.6             24.6

# %%
plt.figure(figsize=(14,8))
sns.barplot(x = TeenBirthRates2017.STATECODE, y = TeenBirthRates2017.mean_birth_rate)
plt.xticks(rotation=90)
plt.grid()
plt.title('Mean Teen Birth Rate 2017')
plt.show()

# %%
TeenBirthRates2017['STATE'] = TeenBirthRates2017['STATECODE'].map(state_abbreviations)
TeenBirthRates2017
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate           STATE
# 0         AK            22.0            22.0             22.0          ALASKA
# 1         AL            27.0            27.0             27.0         ALABAMA
# 2         AR            32.8            32.8             32.8        ARKANSAS
# 3         AZ            22.0            22.0             22.0         ARIZONA
# 4         CA            15.1            15.1             15.1      CALIFORNIA
# 5         CO            16.1            16.1             16.1        COLORADO
# 6         CT             8.8             8.8              8.8     CONNECTICUT
# 7         DE            18.5            18.5             18.5        DELAWARE
# 8         FL            18.2            18.2             18.2         FLORIDA
# 9         GA            21.9            21.9             21.9         GEORGIA
# 10        HI            19.1            19.1             19.1          HAWAII
# 11        IA            16.0            16.0             16.0            IOWA
# 12        ID            18.6            18.6             18.6           IDAHO
# 13        IL            17.4            17.4             17.4        ILLINOIS
# 14        IN            22.8            22.8             22.8         INDIANA
# 15        KS            21.3            21.3             21.3          KANSAS
# 16        KY            29.0            29.0             29.0        KENTUCKY
# 17        LA            29.1            29.1             29.1       LOUISIANA
# 18        MA             8.1             8.1              8.1   MASSACHUSETTS
# 19        MD            14.2            14.2             14.2        MARYLAND
# 20        ME            13.1            13.1             13.1           MAINE
# 21        MI            16.4            16.4             16.4        MICHIGAN
# 22        MN            12.1            12.1             12.1       MINNESOTA
# 23        MO            22.5            22.5             22.5        MISSOURI
# 24        MS            31.0            31.0             31.0     MISSISSIPPI
# 25        MT            21.2            21.2             21.2         MONTANA
# 26        NC            20.6            20.6             20.6  NORTH CAROLINA
# 27        ND            16.2            16.2             16.2    NORTH DAKOTA
# 28        NE            18.1            18.1             18.1        NEBRASKA
# 29        NH             8.4             8.4              8.4   NEW HAMPSHIRE
# 30        NJ            10.3            10.3             10.3      NEW JERSEY
# 31        NM            27.9            27.9             27.9      NEW MEXICO
# 32        NV            21.9            21.9             21.9          NEVADA
# 33        NY            12.5            12.5             12.5        NEW YORK
# 34        OH            20.8            20.8             20.8            OHIO
# 35        OK            29.7            29.7             29.7        OKLAHOMA
# 36        OR            15.0            15.0             15.0          OREGON
# 37        PA            14.8            14.8             14.8    PENNSYLVANIA
# 38        RI            11.4            11.4             11.4    RHODE ISLAND
# 39        SC            21.7            21.7             21.7  SOUTH CAROLINA
# 40        SD            22.6            22.6             22.6    SOUTH DAKOTA
# 41        TN            26.6            26.6             26.6       TENNESSEE
# 42        TX            27.6            27.6             27.6           TEXAS
# 43        UT            15.2            15.2             15.2            UTAH
# 44        VA            15.0            15.0             15.0        VIRGINIA
# 45        VT            10.1            10.1             10.1         VERMONT
# 46        WA            14.8            14.8             14.8      WASHINGTON
# 47        WI            13.8            13.8             13.8       WISCONSIN
# 48        WV            27.1            27.1             27.1   WEST VIRGINIA
# 49        WY            24.6            24.6             24.6         WYOMING

# %%
fig = px.choropleth(TeenBirthRates2017,
                    locationmode='USA-states',
                    scope='usa',
                    locations='STATECODE',
                    color='mean_birth_rate',
                    hover_name='STATE',
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="42977ae9-4add-498a-bee9-b64e3678e39f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42977ae9-4add-498a-bee9-b64e3678e39f")) {                    Plotly.newPlot(                        "42977ae9-4add-498a-bee9-b64e3678e39f",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>STATECODE=%{location}<br>mean_birth_rate=%{z}<extra></extra>","hovertext":["ALASKA","ALABAMA","ARKANSAS","ARIZONA","CALIFORNIA","COLORADO","CONNECTICUT","DELAWARE","FLORIDA","GEORGIA","HAWAII","IOWA","IDAHO","ILLINOIS","INDIANA","KANSAS","KENTUCKY","LOUISIANA","MASSACHUSETTS","MARYLAND","MAINE","MICHIGAN","MINNESOTA","MISSOURI","MISSISSIPPI","MONTANA","NORTH CAROLINA","NORTH DAKOTA","NEBRASKA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEVADA","NEW YORK","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","UTAH","VIRGINIA","VERMONT","WASHINGTON","WISCONSIN","WEST VIRGINIA","WYOMING"],"locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[22.0,27.0,32.8,22.0,15.1,16.1,8.8,18.5,18.2,21.9,19.1,16.0,18.6,17.4,22.8,21.3,29.0,29.1,8.1,14.2,13.1,16.4,12.1,22.5,31.0,21.2,20.6,16.2,18.1,8.4,10.3,27.9,21.9,12.5,20.8,29.7,15.0,14.8,11.4,21.7,22.6,26.6,27.6,15.2,15.0,10.1,14.8,13.8,27.1,24.6],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222 ...

# %%
TeenBirthRates2018 = TeenBirthRates[TeenBirthRates.YEAR == 2018]
TeenBirthRates2018
# Out:
#      YEAR STATECODE  RATE
# 100  2018        AL  25.2
# 101  2018        AK  19.3
# 102  2018        AZ  20.1
# 103  2018        AR  30.4
# 104  2018        CA  13.6
# 105  2018        CO  14.3
# 106  2018        CT   8.3
# 107  2018        DE  16.7
# 108  2018        FL  16.7
# 109  2018        GA  20.6
# 110  2018        HI  17.2
# 111  2018        ID  16.0
# 112  2018        IL  15.8
# 113  2018        IN  21.8
# 114  2018        IA  15.3
# 115  2018        KS  20.0
# 116  2018        KY  27.3
# 117  2018        LA  27.5
# 118  2018        ME  11.1
# 119  2018        MD  14.1
# 120  2018        MA   7.2
# 121  2018        MI  15.8
# 122  2018        MN  10.2
# 123  2018        MS  27.8
# 124  2018        MO  21.6
# 125  2018        MT  17.2
# 126  2018        NE  16.7
# 127  2018        NV  20.5
# 128  2018        NH   8.0
# 129  2018        NJ  10.3
# 130  2018        NM  25.3
# 131  2018        NY  11.7
# 132  2018        NC  18.7
# 133  2018        ND  16.4
# 134  2018        OH  18.9
# 135  2018        OK  27.2
# 136  2018        OR  13.3
# 137  2018        PA  14.1
# 138  2018        RI  11.5
# 139  2018        SC  22.0
# 140  2018        SD  20.4
# 141  2018        TN  25.3
# 142  2018        TX  25.3
# 143  2018        UT  13.1
# 144  2018        VT   8.8
# 145  2018        VA  14.3
# 146  2018        WA  12.7
# 147  2018        WV  25.4
# 148  2018        WI  13.0
# 149  2018        WY  20.8

# %%
TeenBirthRates2018 = TeenBirthRates2018.groupby('STATECODE', as_index=False).agg(
    min_birth_rate = pd.NamedAgg(column='RATE', aggfunc=min),
    max_birth_rate = pd.NamedAgg(column='RATE', aggfunc=max),
    mean_birth_rate = pd.NamedAgg(column='RATE', aggfunc=np.mean))

TeenBirthRates2018
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 0         AK            19.3            19.3             19.3
# 1         AL            25.2            25.2             25.2
# 2         AR            30.4            30.4             30.4
# 3         AZ            20.1            20.1             20.1
# 4         CA            13.6            13.6             13.6
# 5         CO            14.3            14.3             14.3
# 6         CT             8.3             8.3              8.3
# 7         DE            16.7            16.7             16.7
# 8         FL            16.7            16.7             16.7
# 9         GA            20.6            20.6             20.6
# 10        HI            17.2            17.2             17.2
# 11        IA            15.3            15.3             15.3
# 12        ID            16.0            16.0             16.0
# 13        IL            15.8            15.8             15.8
# 14        IN            21.8            21.8             21.8
# 15        KS            20.0            20.0             20.0
# 16        KY            27.3            27.3             27.3
# 17        LA            27.5            27.5             27.5
# 18        MA             7.2             7.2              7.2
# 19        MD            14.1            14.1             14.1
# 20        ME            11.1            11.1             11.1
# 21        MI            15.8            15.8             15.8
# 22        MN            10.2            10.2             10.2
# 23        MO            21.6            21.6             21.6
# 24        MS            27.8            27.8             27.8
# 25        MT            17.2            17.2             17.2
# 26        NC            18.7            18.7             18.7
# 27        ND            16.4            16.4             16.4
# 28        NE            16.7            16.7             16.7
# 29        NH             8.0             8.0              8.0
# 30        NJ            10.3            10.3             10.3
# 31        NM            25.3            25.3             25.3
# 32        NV            20.5            20.5             20.5
# 33        NY            11.7            11.7             11.7
# 34        OH            18.9            18.9             18.9
# 35        OK            27.2            27.2             27.2
# 36        OR            13.3            13.3             13.3
# 37        PA            14.1            14.1             14.1
# 38        RI            11.5            11.5             11.5
# 39        SC            22.0            22.0             22.0
# 40        SD            20.4            20.4             20.4
# 41        TN            25.3            25.3             25.3
# 42        TX            25.3            25.3             25.3
# 43        UT            13.1            13.1             13.1
# 44        VA            14.3            14.3             14.3
# 45        VT             8.8             8.8              8.8
# 46        WA            12.7            12.7             12.7
# 47        WI            13.0            13.0             13.0
# 48        WV            25.4            25.4             25.4
# 49        WY            20.8            20.8             20.8

# %%
plt.figure(figsize=(14,8))
sns.barplot(x = TeenBirthRates2018.STATECODE, y = TeenBirthRates2018.mean_birth_rate)
plt.xticks(rotation=90)
plt.grid()
plt.title('Mean Teen Birth Rate 2018')
plt.show()

# %%
TeenBirthRates2018['STATE'] = TeenBirthRates2018['STATECODE'].map(state_abbreviations)
TeenBirthRates2018
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate           STATE
# 0         AK            19.3            19.3             19.3          ALASKA
# 1         AL            25.2            25.2             25.2         ALABAMA
# 2         AR            30.4            30.4             30.4        ARKANSAS
# 3         AZ            20.1            20.1             20.1         ARIZONA
# 4         CA            13.6            13.6             13.6      CALIFORNIA
# 5         CO            14.3            14.3             14.3        COLORADO
# 6         CT             8.3             8.3              8.3     CONNECTICUT
# 7         DE            16.7            16.7             16.7        DELAWARE
# 8         FL            16.7            16.7             16.7         FLORIDA
# 9         GA            20.6            20.6             20.6         GEORGIA
# 10        HI            17.2            17.2             17.2          HAWAII
# 11        IA            15.3            15.3             15.3            IOWA
# 12        ID            16.0            16.0             16.0           IDAHO
# 13        IL            15.8            15.8             15.8        ILLINOIS
# 14        IN            21.8            21.8             21.8         INDIANA
# 15        KS            20.0            20.0             20.0          KANSAS
# 16        KY            27.3            27.3             27.3        KENTUCKY
# 17        LA            27.5            27.5             27.5       LOUISIANA
# 18        MA             7.2             7.2              7.2   MASSACHUSETTS
# 19        MD            14.1            14.1             14.1        MARYLAND
# 20        ME            11.1            11.1             11.1           MAINE
# 21        MI            15.8            15.8             15.8        MICHIGAN
# 22        MN            10.2            10.2             10.2       MINNESOTA
# 23        MO            21.6            21.6             21.6        MISSOURI
# 24        MS            27.8            27.8             27.8     MISSISSIPPI
# 25        MT            17.2            17.2             17.2         MONTANA
# 26        NC            18.7            18.7             18.7  NORTH CAROLINA
# 27        ND            16.4            16.4             16.4    NORTH DAKOTA
# 28        NE            16.7            16.7             16.7        NEBRASKA
# 29        NH             8.0             8.0              8.0   NEW HAMPSHIRE
# 30        NJ            10.3            10.3             10.3      NEW JERSEY
# 31        NM            25.3            25.3             25.3      NEW MEXICO
# 32        NV            20.5            20.5             20.5          NEVADA
# 33        NY            11.7            11.7             11.7        NEW YORK
# 34        OH            18.9            18.9             18.9            OHIO
# 35        OK            27.2            27.2             27.2        OKLAHOMA
# 36        OR            13.3            13.3             13.3          OREGON
# 37        PA            14.1            14.1             14.1    PENNSYLVANIA
# 38        RI            11.5            11.5             11.5    RHODE ISLAND
# 39        SC            22.0            22.0             22.0  SOUTH CAROLINA
# 40        SD            20.4            20.4             20.4    SOUTH DAKOTA
# 41        TN            25.3            25.3             25.3       TENNESSEE
# 42        TX            25.3            25.3             25.3           TEXAS
# 43        UT            13.1            13.1             13.1            UTAH
# 44        VA            14.3            14.3             14.3        VIRGINIA
# 45        VT             8.8             8.8              8.8         VERMONT
# 46        WA            12.7            12.7             12.7      WASHINGTON
# 47        WI            13.0            13.0             13.0       WISCONSIN
# 48        WV            25.4            25.4             25.4   WEST VIRGINIA
# 49        WY            20.8            20.8             20.8         WYOMING

# %%
fig = px.choropleth(TeenBirthRates2018,
                    locationmode='USA-states',
                    scope='usa',
                    locations='STATECODE',
                    color='mean_birth_rate',
                    hover_name='STATE',
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="5a00d753-0bdc-49d3-ba76-cf21a9a687a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a00d753-0bdc-49d3-ba76-cf21a9a687a2")) {                    Plotly.newPlot(                        "5a00d753-0bdc-49d3-ba76-cf21a9a687a2",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>STATECODE=%{location}<br>mean_birth_rate=%{z}<extra></extra>","hovertext":["ALASKA","ALABAMA","ARKANSAS","ARIZONA","CALIFORNIA","COLORADO","CONNECTICUT","DELAWARE","FLORIDA","GEORGIA","HAWAII","IOWA","IDAHO","ILLINOIS","INDIANA","KANSAS","KENTUCKY","LOUISIANA","MASSACHUSETTS","MARYLAND","MAINE","MICHIGAN","MINNESOTA","MISSOURI","MISSISSIPPI","MONTANA","NORTH CAROLINA","NORTH DAKOTA","NEBRASKA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEVADA","NEW YORK","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","UTAH","VIRGINIA","VERMONT","WASHINGTON","WISCONSIN","WEST VIRGINIA","WYOMING"],"locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[19.3,25.2,30.4,20.1,13.6,14.3,8.3,16.7,16.7,20.6,17.2,15.3,16.0,15.8,21.8,20.0,27.3,27.5,7.2,14.1,11.1,15.8,10.2,21.6,27.8,17.2,18.7,16.4,16.7,8.0,10.3,25.3,20.5,11.7,18.9,27.2,13.3,14.1,11.5,22.0,20.4,25.3,25.3,13.1,14.3,8.8,12.7,13.0,25.4,20.8],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222 ...

# %%
TeenBirthRates2019 = TeenBirthRates[TeenBirthRates.YEAR == 2019]
TeenBirthRates2019
# Out:
#     YEAR STATECODE  RATE
# 50  2019        AL  25.6
# 51  2019        AK  18.3
# 52  2019        AZ  18.5
# 53  2019        AR  30.0
# 54  2019        CA  12.4
# 55  2019        CO  13.9
# 56  2019        CT   7.7
# 57  2019        DE  14.9
# 58  2019        FL  16.2
# 59  2019        GA  19.7
# 60  2019        HI  15.7
# 61  2019        ID  14.9
# 62  2019        IL  14.6
# 63  2019        IN  20.8
# 64  2019        IA  14.1
# 65  2019        KS  19.2
# 66  2019        KY  24.9
# 67  2019        LA  27.8
# 68  2019        ME   9.1
# 69  2019        MD  13.9
# 70  2019        MA   6.9
# 71  2019        MI  15.1
# 72  2019        MN  10.1
# 73  2019        MS  29.1
# 74  2019        MO  20.3
# 75  2019        MT  16.3
# 76  2019        NE  15.3
# 77  2019        NV  18.9
# 78  2019        NH   6.6
# 79  2019        NJ  10.0
# 80  2019        NM  24.4
# 81  2019        NY  11.4
# 82  2019        NC  18.2
# 83  2019        ND  15.6
# 84  2019        OH  18.8
# 85  2019        OK  27.4
# 86  2019        OR  12.1
# 87  2019        PA  13.3
# 88  2019        RI  10.0
# 89  2019        SC  21.6
# 90  2019        SD  19.2
# 91  2019        TN  23.7
# 92  2019        TX  24.0
# 93  2019        UT  12.0
# 94  2019        VT   7.6
# 95  2019        VA  13.6
# 96  2019        WA  12.7
# 97  2019        WV  25.2
# 98  2019        WI  12.5
# 99  2019        WY  19.4

# %%
TeenBirthRates2019 = TeenBirthRates2019.groupby('STATECODE', as_index=False).agg(
    min_birth_rate = pd.NamedAgg(column='RATE', aggfunc=min),
    max_birth_rate = pd.NamedAgg(column='RATE', aggfunc=max),
    mean_birth_rate = pd.NamedAgg(column='RATE', aggfunc=np.mean))

TeenBirthRates2019
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 0         AK            18.3            18.3             18.3
# 1         AL            25.6            25.6             25.6
# 2         AR            30.0            30.0             30.0
# 3         AZ            18.5            18.5             18.5
# 4         CA            12.4            12.4             12.4
# 5         CO            13.9            13.9             13.9
# 6         CT             7.7             7.7              7.7
# 7         DE            14.9            14.9             14.9
# 8         FL            16.2            16.2             16.2
# 9         GA            19.7            19.7             19.7
# 10        HI            15.7            15.7             15.7
# 11        IA            14.1            14.1             14.1
# 12        ID            14.9            14.9             14.9
# 13        IL            14.6            14.6             14.6
# 14        IN            20.8            20.8             20.8
# 15        KS            19.2            19.2             19.2
# 16        KY            24.9            24.9             24.9
# 17        LA            27.8            27.8             27.8
# 18        MA             6.9             6.9              6.9
# 19        MD            13.9            13.9             13.9
# 20        ME             9.1             9.1              9.1
# 21        MI            15.1            15.1             15.1
# 22        MN            10.1            10.1             10.1
# 23        MO            20.3            20.3             20.3
# 24        MS            29.1            29.1             29.1
# 25        MT            16.3            16.3             16.3
# 26        NC            18.2            18.2             18.2
# 27        ND            15.6            15.6             15.6
# 28        NE            15.3            15.3             15.3
# 29        NH             6.6             6.6              6.6
# 30        NJ            10.0            10.0             10.0
# 31        NM            24.4            24.4             24.4
# 32        NV            18.9            18.9             18.9
# 33        NY            11.4            11.4             11.4
# 34        OH            18.8            18.8             18.8
# 35        OK            27.4            27.4             27.4
# 36        OR            12.1            12.1             12.1
# 37        PA            13.3            13.3             13.3
# 38        RI            10.0            10.0             10.0
# 39        SC            21.6            21.6             21.6
# 40        SD            19.2            19.2             19.2
# 41        TN            23.7            23.7             23.7
# 42        TX            24.0            24.0             24.0
# 43        UT            12.0            12.0             12.0
# 44        VA            13.6            13.6             13.6
# 45        VT             7.6             7.6              7.6
# 46        WA            12.7            12.7             12.7
# 47        WI            12.5            12.5             12.5
# 48        WV            25.2            25.2             25.2
# 49        WY            19.4            19.4             19.4

# %%
plt.figure(figsize=(14,8))
sns.barplot(x = TeenBirthRates2019.STATECODE, y = TeenBirthRates2019.mean_birth_rate)
plt.xticks(rotation=90)
plt.grid()
plt.title('Mean Teen Birth Rate 2019')
plt.show()

# %%
TeenBirthRates2019['STATE'] = TeenBirthRates2019['STATECODE'].map(state_abbreviations)
TeenBirthRates2019
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate           STATE
# 0         AK            18.3            18.3             18.3          ALASKA
# 1         AL            25.6            25.6             25.6         ALABAMA
# 2         AR            30.0            30.0             30.0        ARKANSAS
# 3         AZ            18.5            18.5             18.5         ARIZONA
# 4         CA            12.4            12.4             12.4      CALIFORNIA
# 5         CO            13.9            13.9             13.9        COLORADO
# 6         CT             7.7             7.7              7.7     CONNECTICUT
# 7         DE            14.9            14.9             14.9        DELAWARE
# 8         FL            16.2            16.2             16.2         FLORIDA
# 9         GA            19.7            19.7             19.7         GEORGIA
# 10        HI            15.7            15.7             15.7          HAWAII
# 11        IA            14.1            14.1             14.1            IOWA
# 12        ID            14.9            14.9             14.9           IDAHO
# 13        IL            14.6            14.6             14.6        ILLINOIS
# 14        IN            20.8            20.8             20.8         INDIANA
# 15        KS            19.2            19.2             19.2          KANSAS
# 16        KY            24.9            24.9             24.9        KENTUCKY
# 17        LA            27.8            27.8             27.8       LOUISIANA
# 18        MA             6.9             6.9              6.9   MASSACHUSETTS
# 19        MD            13.9            13.9             13.9        MARYLAND
# 20        ME             9.1             9.1              9.1           MAINE
# 21        MI            15.1            15.1             15.1        MICHIGAN
# 22        MN            10.1            10.1             10.1       MINNESOTA
# 23        MO            20.3            20.3             20.3        MISSOURI
# 24        MS            29.1            29.1             29.1     MISSISSIPPI
# 25        MT            16.3            16.3             16.3         MONTANA
# 26        NC            18.2            18.2             18.2  NORTH CAROLINA
# 27        ND            15.6            15.6             15.6    NORTH DAKOTA
# 28        NE            15.3            15.3             15.3        NEBRASKA
# 29        NH             6.6             6.6              6.6   NEW HAMPSHIRE
# 30        NJ            10.0            10.0             10.0      NEW JERSEY
# 31        NM            24.4            24.4             24.4      NEW MEXICO
# 32        NV            18.9            18.9             18.9          NEVADA
# 33        NY            11.4            11.4             11.4        NEW YORK
# 34        OH            18.8            18.8             18.8            OHIO
# 35        OK            27.4            27.4             27.4        OKLAHOMA
# 36        OR            12.1            12.1             12.1          OREGON
# 37        PA            13.3            13.3             13.3    PENNSYLVANIA
# 38        RI            10.0            10.0             10.0    RHODE ISLAND
# 39        SC            21.6            21.6             21.6  SOUTH CAROLINA
# 40        SD            19.2            19.2             19.2    SOUTH DAKOTA
# 41        TN            23.7            23.7             23.7       TENNESSEE
# 42        TX            24.0            24.0             24.0           TEXAS
# 43        UT            12.0            12.0             12.0            UTAH
# 44        VA            13.6            13.6             13.6        VIRGINIA
# 45        VT             7.6             7.6              7.6         VERMONT
# 46        WA            12.7            12.7             12.7      WASHINGTON
# 47        WI            12.5            12.5             12.5       WISCONSIN
# 48        WV            25.2            25.2             25.2   WEST VIRGINIA
# 49        WY            19.4            19.4             19.4         WYOMING

# %%
fig = px.choropleth(TeenBirthRates2019,
                    locationmode='USA-states',
                    scope='usa',
                    locations='STATECODE',
                    color='mean_birth_rate',
                    hover_name='STATE',
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="3891d024-c8bf-493e-99ba-184c88e924d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3891d024-c8bf-493e-99ba-184c88e924d3")) {                    Plotly.newPlot(                        "3891d024-c8bf-493e-99ba-184c88e924d3",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>STATECODE=%{location}<br>mean_birth_rate=%{z}<extra></extra>","hovertext":["ALASKA","ALABAMA","ARKANSAS","ARIZONA","CALIFORNIA","COLORADO","CONNECTICUT","DELAWARE","FLORIDA","GEORGIA","HAWAII","IOWA","IDAHO","ILLINOIS","INDIANA","KANSAS","KENTUCKY","LOUISIANA","MASSACHUSETTS","MARYLAND","MAINE","MICHIGAN","MINNESOTA","MISSOURI","MISSISSIPPI","MONTANA","NORTH CAROLINA","NORTH DAKOTA","NEBRASKA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEVADA","NEW YORK","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","UTAH","VIRGINIA","VERMONT","WASHINGTON","WISCONSIN","WEST VIRGINIA","WYOMING"],"locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[18.3,25.6,30.0,18.5,12.4,13.9,7.7,14.9,16.2,19.7,15.7,14.1,14.9,14.6,20.8,19.2,24.9,27.8,6.9,13.9,9.1,15.1,10.1,20.3,29.1,16.3,18.2,15.6,15.3,6.6,10.0,24.4,18.9,11.4,18.8,27.4,12.1,13.3,10.0,21.6,19.2,23.7,24.0,12.0,13.6,7.6,12.7,12.5,25.2,19.4],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222 ...

# %%
TeenBirthRates2020 = TeenBirthRates[TeenBirthRates.YEAR == 2020]
TeenBirthRates2020
# Out:
#     YEAR STATECODE  RATE
# 0   2020        AL  24.8
# 1   2020        AK  17.7
# 2   2020        AZ  16.6
# 3   2020        AR  27.8
# 4   2020        CA  11.0
# 5   2020        CO  12.5
# 6   2020        CT   7.6
# 7   2020        DE  14.6
# 8   2020        FL  15.2
# 9   2020        GA  18.2
# 10  2020        HI  13.0
# 11  2020        ID  14.6
# 12  2020        IL  13.6
# 13  2020        IN  18.7
# 14  2020        IA  13.3
# 15  2020        KS  18.1
# 16  2020        KY  23.8
# 17  2020        LA  25.7
# 18  2020        ME  10.6
# 19  2020        MD  13.1
# 20  2020        MA   6.1
# 21  2020        MI  13.5
# 22  2020        MN   9.1
# 23  2020        MS  27.9
# 24  2020        MO  18.8
# 25  2020        MT  13.2
# 26  2020        NE  15.1
# 27  2020        NV  16.8
# 28  2020        NH   6.6
# 29  2020        NJ   9.2
# 30  2020        NM  21.9
# 31  2020        NY  10.0
# 32  2020        NC  17.3
# 33  2020        ND  13.7
# 34  2020        OH  17.6
# 35  2020        OK  25.0
# 36  2020        OR  10.1
# 37  2020        PA  12.6
# 38  2020        RI   9.4
# 39  2020        SC  19.3
# 40  2020        SD  18.7
# 41  2020        TN  23.3
# 42  2020        TX  22.4
# 43  2020        UT  10.8
# 44  2020        VT   7.0
# 45  2020        VA  13.1
# 46  2020        WA  11.3
# 47  2020        WV  22.5
# 48  2020        WI  11.5
# 49  2020        WY  18.1

# %%
TeenBirthRates2020 = TeenBirthRates2020.groupby('STATECODE', as_index=False).agg(
    min_birth_rate = pd.NamedAgg(column='RATE', aggfunc=min),
    max_birth_rate = pd.NamedAgg(column='RATE', aggfunc=max),
    mean_birth_rate = pd.NamedAgg(column='RATE', aggfunc=np.mean))

TeenBirthRates2020
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 0         AK            17.7            17.7             17.7
# 1         AL            24.8            24.8             24.8
# 2         AR            27.8            27.8             27.8
# 3         AZ            16.6            16.6             16.6
# 4         CA            11.0            11.0             11.0
# 5         CO            12.5            12.5             12.5
# 6         CT             7.6             7.6              7.6
# 7         DE            14.6            14.6             14.6
# 8         FL            15.2            15.2             15.2
# 9         GA            18.2            18.2             18.2
# 10        HI            13.0            13.0             13.0
# 11        IA            13.3            13.3             13.3
# 12        ID            14.6            14.6             14.6
# 13        IL            13.6            13.6             13.6
# 14        IN            18.7            18.7             18.7
# 15        KS            18.1            18.1             18.1
# 16        KY            23.8            23.8             23.8
# 17        LA            25.7            25.7             25.7
# 18        MA             6.1             6.1              6.1
# 19        MD            13.1            13.1             13.1
# 20        ME            10.6            10.6             10.6
# 21        MI            13.5            13.5             13.5
# 22        MN             9.1             9.1              9.1
# 23        MO            18.8            18.8             18.8
# 24        MS            27.9            27.9             27.9
# 25        MT            13.2            13.2             13.2
# 26        NC            17.3            17.3             17.3
# 27        ND            13.7            13.7             13.7
# 28        NE            15.1            15.1             15.1
# 29        NH             6.6             6.6              6.6
# 30        NJ             9.2             9.2              9.2
# 31        NM            21.9            21.9             21.9
# 32        NV            16.8            16.8             16.8
# 33        NY            10.0            10.0             10.0
# 34        OH            17.6            17.6             17.6
# 35        OK            25.0            25.0             25.0
# 36        OR            10.1            10.1             10.1
# 37        PA            12.6            12.6             12.6
# 38        RI             9.4             9.4              9.4
# 39        SC            19.3            19.3             19.3
# 40        SD            18.7            18.7             18.7
# 41        TN            23.3            23.3             23.3
# 42        TX            22.4            22.4             22.4
# 43        UT            10.8            10.8             10.8
# 44        VA            13.1            13.1             13.1
# 45        VT             7.0             7.0              7.0
# 46        WA            11.3            11.3             11.3
# 47        WI            11.5            11.5             11.5
# 48        WV            22.5            22.5             22.5
# 49        WY            18.1            18.1             18.1

# %%
plt.figure(figsize=(14,8))
sns.barplot(x = TeenBirthRates2020.STATECODE, y = TeenBirthRates2020.mean_birth_rate)
plt.xticks(rotation=90)
plt.grid()
plt.title('Mean Teen Birth Rate 2020')
plt.show()

# %%
TeenBirthRates2020['STATE'] = TeenBirthRates2020['STATECODE'].map(state_abbreviations)
TeenBirthRates2020
# Out:
#    STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate           STATE
# 0         AK            17.7            17.7             17.7          ALASKA
# 1         AL            24.8            24.8             24.8         ALABAMA
# 2         AR            27.8            27.8             27.8        ARKANSAS
# 3         AZ            16.6            16.6             16.6         ARIZONA
# 4         CA            11.0            11.0             11.0      CALIFORNIA
# 5         CO            12.5            12.5             12.5        COLORADO
# 6         CT             7.6             7.6              7.6     CONNECTICUT
# 7         DE            14.6            14.6             14.6        DELAWARE
# 8         FL            15.2            15.2             15.2         FLORIDA
# 9         GA            18.2            18.2             18.2         GEORGIA
# 10        HI            13.0            13.0             13.0          HAWAII
# 11        IA            13.3            13.3             13.3            IOWA
# 12        ID            14.6            14.6             14.6           IDAHO
# 13        IL            13.6            13.6             13.6        ILLINOIS
# 14        IN            18.7            18.7             18.7         INDIANA
# 15        KS            18.1            18.1             18.1          KANSAS
# 16        KY            23.8            23.8             23.8        KENTUCKY
# 17        LA            25.7            25.7             25.7       LOUISIANA
# 18        MA             6.1             6.1              6.1   MASSACHUSETTS
# 19        MD            13.1            13.1             13.1        MARYLAND
# 20        ME            10.6            10.6             10.6           MAINE
# 21        MI            13.5            13.5             13.5        MICHIGAN
# 22        MN             9.1             9.1              9.1       MINNESOTA
# 23        MO            18.8            18.8             18.8        MISSOURI
# 24        MS            27.9            27.9             27.9     MISSISSIPPI
# 25        MT            13.2            13.2             13.2         MONTANA
# 26        NC            17.3            17.3             17.3  NORTH CAROLINA
# 27        ND            13.7            13.7             13.7    NORTH DAKOTA
# 28        NE            15.1            15.1             15.1        NEBRASKA
# 29        NH             6.6             6.6              6.6   NEW HAMPSHIRE
# 30        NJ             9.2             9.2              9.2      NEW JERSEY
# 31        NM            21.9            21.9             21.9      NEW MEXICO
# 32        NV            16.8            16.8             16.8          NEVADA
# 33        NY            10.0            10.0             10.0        NEW YORK
# 34        OH            17.6            17.6             17.6            OHIO
# 35        OK            25.0            25.0             25.0        OKLAHOMA
# 36        OR            10.1            10.1             10.1          OREGON
# 37        PA            12.6            12.6             12.6    PENNSYLVANIA
# 38        RI             9.4             9.4              9.4    RHODE ISLAND
# 39        SC            19.3            19.3             19.3  SOUTH CAROLINA
# 40        SD            18.7            18.7             18.7    SOUTH DAKOTA
# 41        TN            23.3            23.3             23.3       TENNESSEE
# 42        TX            22.4            22.4             22.4           TEXAS
# 43        UT            10.8            10.8             10.8            UTAH
# 44        VA            13.1            13.1             13.1        VIRGINIA
# 45        VT             7.0             7.0              7.0         VERMONT
# 46        WA            11.3            11.3             11.3      WASHINGTON
# 47        WI            11.5            11.5             11.5       WISCONSIN
# 48        WV            22.5            22.5             22.5   WEST VIRGINIA
# 49        WY            18.1            18.1             18.1         WYOMING

# %%
fig = px.choropleth(TeenBirthRates2020,
                    locationmode='USA-states',
                    scope='usa',
                    locations='STATECODE',
                    color='mean_birth_rate',
                    hover_name='STATE',
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <div>                            <div id="7c6d3ec5-25a5-45d8-b5b9-bbb13e584a4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c6d3ec5-25a5-45d8-b5b9-bbb13e584a4e")) {                    Plotly.newPlot(                        "7c6d3ec5-25a5-45d8-b5b9-bbb13e584a4e",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>STATECODE=%{location}<br>mean_birth_rate=%{z}<extra></extra>","hovertext":["ALASKA","ALABAMA","ARKANSAS","ARIZONA","CALIFORNIA","COLORADO","CONNECTICUT","DELAWARE","FLORIDA","GEORGIA","HAWAII","IOWA","IDAHO","ILLINOIS","INDIANA","KANSAS","KENTUCKY","LOUISIANA","MASSACHUSETTS","MARYLAND","MAINE","MICHIGAN","MINNESOTA","MISSOURI","MISSISSIPPI","MONTANA","NORTH CAROLINA","NORTH DAKOTA","NEBRASKA","NEW HAMPSHIRE","NEW JERSEY","NEW MEXICO","NEVADA","NEW YORK","OHIO","OKLAHOMA","OREGON","PENNSYLVANIA","RHODE ISLAND","SOUTH CAROLINA","SOUTH DAKOTA","TENNESSEE","TEXAS","UTAH","VIRGINIA","VERMONT","WASHINGTON","WISCONSIN","WEST VIRGINIA","WYOMING"],"locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"],"name":"","z":[17.7,24.8,27.8,16.6,11.0,12.5,7.6,14.6,15.2,18.2,13.0,13.3,14.6,13.6,18.7,18.1,23.8,25.7,6.1,13.1,10.6,13.5,9.1,18.8,27.9,13.2,17.3,13.7,15.1,6.6,9.2,21.9,16.8,10.0,17.6,25.0,10.1,12.6,9.4,19.3,18.7,23.3,22.4,10.8,13.1,7.0,11.3,11.5,22.5,18.1],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222222222222 ...

# %% [markdown]
# # Trend over time by state (2014-2020)

# %%
TeenBirthRates = TeenBirthRates.groupby(['YEAR','STATECODE'], as_index=False).agg(
    min_birth_rate = pd.NamedAgg(column='RATE', aggfunc=min),
    max_birth_rate = pd.NamedAgg(column='RATE', aggfunc=max),
    mean_birth_rate = pd.NamedAgg(column='RATE', aggfunc=np.mean))

TeenBirthRates
# Out:
#      YEAR STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 0    2014        AK            27.8            27.8             27.8
# 1    2014        AL            32.0            32.0             32.0
# 2    2014        AR            39.5            39.5             39.5
# 3    2014        AZ            29.9            29.9             29.9
# 4    2014        CA            21.1            21.1             21.1
# ..    ...       ...             ...             ...              ...
# 345  2020        VT             7.0             7.0              7.0
# 346  2020        WA            11.3            11.3             11.3
# 347  2020        WI            11.5            11.5             11.5
# 348  2020        WV            22.5            22.5             22.5
# 349  2020        WY            18.1            18.1             18.1
#
# [350 rows x 5 columns]

# %% [markdown]
# ### Select a specific state

# %%
select_state='AR'
TeenBirthRates_by_State = TeenBirthRates[TeenBirthRates.STATECODE==select_state]
TeenBirthRates_by_State
# Out:
#      YEAR STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 2    2014        AR            39.5            39.5             39.5
# 52   2015        AR            38.0            38.0             38.0
# 102  2016        AR            34.6            34.6             34.6
# 152  2017        AR            32.8            32.8             32.8
# 202  2018        AR            30.4            30.4             30.4
# 252  2019        AR            30.0            30.0             30.0
# 302  2020        AR            27.8            27.8             27.8

# %%
plt.figure(figsize=(7,4))
plt.plot(TeenBirthRates_by_State.YEAR, TeenBirthRates_by_State.mean_birth_rate)
plt.grid()
plt.title('Mean Birth Rate - ARKANSAS')
plt.show()

# %% [markdown]
# ### Select another State

# %%
select_state='MA'
TeenBirthRates_by_State = TeenBirthRates[TeenBirthRates.STATECODE==select_state]
TeenBirthRates_by_State
# Out:
#      YEAR STATECODE  min_birth_rate  max_birth_rate  mean_birth_rate
# 18   2014        MA            10.6            10.6             10.6
# 68   2015        MA             9.4             9.4              9.4
# 118  2016        MA             8.5             8.5              8.5
# 168  2017        MA             8.1             8.1              8.1
# 218  2018        MA             7.2             7.2              7.2
# 268  2019        MA             6.9             6.9              6.9
# 318  2020        MA             6.1             6.1              6.1

# %%
plt.figure(figsize=(7,4))
plt.plot(TeenBirthRates_by_State.YEAR, TeenBirthRates_by_State.mean_birth_rate)
plt.grid()
plt.title('Mean Birth Rate - Massachusetts')
plt.show()

# %% [markdown]
# ### Select all states

# %%
plt.figure(figsize=(12,8))
sns.lineplot('YEAR','mean_birth_rate', hue='STATECODE', data=TeenBirthRates)
plt.grid()
plt.title('Mean Birth Rate')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
# Out:
# /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
TeenBirthRates2014['mean_birth_rate'].hist()
# Out:
# <AxesSubplot:>

# %%
TeenBirthRates2020['mean_birth_rate'].hist()
# Out:
# <AxesSubplot:>

# %%
stats.ttest_rel(TeenBirthRates2014['mean_birth_rate'],TeenBirthRates2020['mean_birth_rate'])
# Out:
# Ttest_relResult(statistic=21.300954057125114, pvalue=2.0094058825377888e-26)
