# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
TeenBirthRates = pd.read_csv("Teen rates by state.csv")

# %%
TeenBirthRates.head()
# Out:
#    YEAR STATE  RATE                                       URL
# 0  2020    AL  24.8     /nchs/pressroom/states/alabama/al.htm
# 1  2020    AK  17.7      /nchs/pressroom/states/alaska/ak.htm
# 2  2020    AZ  16.6     /nchs/pressroom/states/arizona/az.htm
# 3  2020    AR  27.8    /nchs/pressroom/states/arkansas/ar.htm
# 4  2020    CA  11.0  /nchs/pressroom/states/california/ca.htm

# %%
TeenBirthRates.tail()
# Out:
#      YEAR STATE  RATE                                                URL
# 395  2005    VA  34.4       /nchs/pressroom/states/virginia/virginia.htm
# 396  2005    WA  31.1   /nchs/pressroom/states/washington/washington.htm
# 397  2005    WV  43.4  /nchs/pressroom/states/westvirginia/westvirgin...
# 398  2005    WI  30.3     /nchs/pressroom/states/wisconsin/wisconsin.htm
# 399  2005    WY  43.2         /nchs/pressroom/states/wyoming/wyoming.htm

# %%
TeenBirthRates.shape
# Out:
# (400, 4)

# %%
TeenBirthRates.drop("URL", axis = 1, inplace=True)

# %%
TeenBirthRates.head()
# Out:
#    YEAR STATE  RATE
# 0  2020    AL  24.8
# 1  2020    AK  17.7
# 2  2020    AZ  16.6
# 3  2020    AR  27.8
# 4  2020    CA  11.0

# %%
TeenBirthRates2005 = TeenBirthRates2[TeenBirthRates2.YEAR == 2005]

# %%
TeenBirthRates2005
# Out:
#      YEAR STATE  RATE
# 350  2005    AL  49.7
# 351  2005    AK  37.3
# 352  2005    AZ  58.2
# 353  2005    AR  59.1
# 354  2005    CA  38.8
# 355  2005    CO  42.6
# 356  2005    CT  23.3
# 357  2005    DE  44.0
# 358  2005    FL  42.4
# 359  2005    GA  52.7
# 360  2005    HI  36.2
# 361  2005    ID  37.7
# 362  2005    IL  38.6
# 363  2005    IN  43.2
# 364  2005    IA  32.6
# 365  2005    KS  41.4
# 366  2005    KY  49.1
# 367  2005    LA  49.1
# 368  2005    ME  24.4
# 369  2005    MD  31.8
# 370  2005    MA  21.8
# 371  2005    MI  32.5
# 372  2005    MN  26.1
# 373  2005    MS  60.5
# 374  2005    MO  42.5
# 375  2005    MT  35.2
# 376  2005    NE  34.2
# 377  2005    NV  50.1
# 378  2005    NH  17.9
# 379  2005    NJ  23.4
# 380  2005    NM  61.6
# 381  2005    NY  26.5
# 382  2005    NC  48.5
# 383  2005    ND  29.7
# 384  2005    OH  38.9
# 385  2005    OK  54.2
# 386  2005    OR  33.0
# 387  2005    PA  30.4
# 388  2005    RI  31.4
# 389  2005    SC  51.0
# ...

# %%
plt.figure(figsize=(14,8))
sns.barplot(x = TeenBirthRates2005.STATE, y = TeenBirthRates2005.RATE)
plt.xticks(rotation=90)
plt.grid()
plt.title('Teen Birth Rate 2005')
plt.show()

# %%
TeenBirthRates2020 = TeenBirthRates2[TeenBirthRates2.YEAR == 2020]

# %%
TeenBirthRates2020
# Out:
#     YEAR STATE  RATE
# 0   2020    AL  24.8
# 1   2020    AK  17.7
# 2   2020    AZ  16.6
# 3   2020    AR  27.8
# 4   2020    CA  11.0
# 5   2020    CO  12.5
# 6   2020    CT   7.6
# 7   2020    DE  14.6
# 8   2020    FL  15.2
# 9   2020    GA  18.2
# 10  2020    HI  13.0
# 11  2020    ID  14.6
# 12  2020    IL  13.6
# 13  2020    IN  18.7
# 14  2020    IA  13.3
# 15  2020    KS  18.1
# 16  2020    KY  23.8
# 17  2020    LA  25.7
# 18  2020    ME  10.6
# 19  2020    MD  13.1
# 20  2020    MA   6.1
# 21  2020    MI  13.5
# 22  2020    MN   9.1
# 23  2020    MS  27.9
# 24  2020    MO  18.8
# 25  2020    MT  13.2
# 26  2020    NE  15.1
# 27  2020    NV  16.8
# 28  2020    NH   6.6
# 29  2020    NJ   9.2
# 30  2020    NM  21.9
# 31  2020    NY  10.0
# 32  2020    NC  17.3
# 33  2020    ND  13.7
# 34  2020    OH  17.6
# 35  2020    OK  25.0
# 36  2020    OR  10.1
# 37  2020    PA  12.6
# 38  2020    RI   9.4
# 39  2020    SC  19.3
# 40  2020    SD  18.7
# 41  2020    TN  23.3
# ...

# %%
plt.figure(figsize=(14,8))
sns.barplot(x = TeenBirthRates2020.STATE, y = TeenBirthRates2020.RATE)
plt.xticks(rotation=90)
plt.grid()
plt.title('Teen Birth Rate 2020')
plt.show()

# %% [markdown]
# # Trend over time by state (2005-2020)

# %%
plt.figure(figsize=(12,8))
sns.lineplot('YEAR','RATE', hue ='STATE', data=TeenBirthRates)
plt.grid()
plt.title('Birth Rate')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
# Out:
# /Users/lucythuku/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
